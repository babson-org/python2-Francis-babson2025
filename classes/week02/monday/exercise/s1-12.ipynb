# %% [markdown]
# # Starter Python Notebook
# This notebook contains 12 practice questions with sample solutions. Each solution includes comments explaining the code.

# %% [markdown]
# ## Question 1 - Make Tea Function

# %%
# Define the steps to make tea
steps = [
    'get teapot with water',
    'get cup',
    'get teabag',
    'turn stove on',
    'place teapot on stove',
    'boil water',
    'pour water into cup',
    'add teabag',
    'dunk 37 times',
    'enjoy tea'
]

# Function to print each step
def make_tea(entries):
    for s in entries:
        print(s)

# Call the function
make_tea(steps)

# %% [markdown]
# ## Question 2 - Next Numbers in a List

# %%
pattern = [2, 4, 6, 8, 10]
# Calculate next three numbers by continuing the pattern
for _ in range(3):
    next_num = pattern[-1] + 2
    pattern.append(next_num)
    print(next_num)

# %% [markdown]
# ## Question 3 - Greeting User

# %%
# Ask for first and last name
fname = input('Please enter your first name: ')
lname = input('Please enter your last name: ')
# Print greeting using f-string
print(f'Hello, {fname} {lname}!')

# %% [markdown]
# ## Question 4 - Python Version and Platform

# %%
import sys
import platform
# Print Python version and platform
print('Python Version:', sys.version)
print('Platform:', platform.system(), platform.release())

# %% [markdown]
# ## Question 5 - Arithmetic Operations

# %%
x = float(input('Enter first number: '))
y = float(input('Enter second number: '))
# Perform calculations
print('Sum:', x + y)
print('Difference:', x - y)
print('Product:', x * y)
print('Division:', x / y)
print('Floor Division:', x // y)

# %% [markdown]
# ## Question 6 - Text Transformations

# %%
txt = input('Enter a sentence: ')
# Print transformations
print('Uppercase:', txt.upper())
print('Lowercase:', txt.lower())
print('Capitalized:', txt.capitalize())
print('Split into words:', txt.split())

# %% [markdown]
# ## Question 7 - Operator Precedence

# %%
# Without parentheses
result1 = 10 + 2 * 5 / 2 - 2 ** 3 ** 2
# With parentheses for clarity
result2 = 10 + (2 * 5 / 2) - 2 ** (3 ** 2)
result3 = (10 + (2 * 5 / 2) - (2 ** 3) ** 2)
print('Without parentheses:', result1)
print('With parentheses (nested):', result2)
print('With parentheses ((2**3)**2):', result3)

# %% [markdown]
# ## Question 8 - Modify List

# %%
favorites = ['ice cream', 'pizza', 'cake']
# Replace second item
favorites[1] = 'blueberries'
print('Updated favorites:', favorites)

# %% [markdown]
# ## Question 9 - Tuple Immutability

# %%
numbers = (1, 2, 3, 4)
# Trying to modify a tuple will cause an error
try:
    numbers[0] = 5
except TypeError:
    print('Tuples are immutable and cannot be changed')
print('Tuple remains:', numbers)

# %% [markdown]
# ## Question 10 - Dictionary and List

# %%
from pprint import pprint
student = {'name': 'Bob', 'age': 25}
# Update age
student['age'] = 37
# Add favorite numbers
fav_nums = [7, 666, 42]
student['favorites'] = fav_nums
print('Student dictionary:')
pprint(student)

# %% [markdown]
# ## Question 11 - Save and Read Quote

# %%
quote = input('Enter your favorite quote: ')
# Save to file
with open('quote.txt', 'w') as f:
    f.write(quote)
# Read back and print
with open('quote.txt', 'r') as f:
    saved_quote = f.read()
print('Your quote:', saved_quote)

# %% [markdown]
# ## Question 12 - Sum and Average

# %%
numbers = []
for i in range(5):
    num = int(input(f'Enter number {i+1}: '))
    numbers.append(num)
total = sum(numbers)
average = total / len(numbers)
print('Numbers:', numbers)
print('Total:', total)
print('Average:', average)
